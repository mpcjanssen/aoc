# %%
source [file join . modules util.tcl]

# %%
set data [read-input day08];

# %%
set width 25
set height 6
set layersize [expr {$width*$height}]
set pat [string repeat . $layersize]
set layers [regexp -all -inline $pat $data]

proc freq1s {d} {
  dict get $d 1
}

proc part1 {} {
  set min0freqs [lindex [lsort -integer -index 1 [lmap x $::layers {lsort -integer -stride 2 -index 0 [freq $x]}]] 0]
  return [expr {[dict get $min0freqs 1]*[dict get $min0freqs 2]}]
}

# %%
part1
# Out:
# 2193

# %%
proc visualize-step {} {
  set layer 0
  set svgid [jupyter::html {<svg width="250" height="60"></svg>}]
  yield
  set svg [lrepeat 150 {}]
  foreach l [lreverse $::layers] {
    incr layer
    foreach y [range 0 5] {
       foreach x [range 0 24] {
       set idx [expr {$y*25+$x} ]
        set col [string index $l $idx]
        switch $col {
          0 {
              lset svg $idx {}
          }
          1 {
              lset svg $idx [svgrect $x $y 10]
          }
          
        }
      }
    }
    jupyter::updatehtml $svgid "<b>layer: </b> $layer<br><svg viewbox=\"-10 -10 260 70\">[join $svg \n]</svg>"
    yield 1
  }
  yield 0
}

# %%
coroutine visualize visualize-step
while {[visualize]} {}
# Out:
# <b>layer: </b> 100<br><svg viewbox="-10 -10 260 70"><rect x="0" y = "0" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
#
#
# <rect x="40" y = "0" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="50" y = "0" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="60" y = "0" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="70" y = "0" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="80" y = "0" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
# <rect x="100" y = "0" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
#
# <rect x="130" y = "0" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
# <rect x="150" y = "0" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="160" y = "0" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="170" y = "0" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="180" y = "0" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
# <rect x="200" y = "0" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="210" y = "0" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="220" y = "0" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="230" y = "0" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
# <rect x="0" y = "10" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
#
#
# <rect x="40" y = "10" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="50" y = "10" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
#
#
#
# <rect x="100" y = "10" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
#
# <rect x="130" y = "10" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
# <rect x="150" y = "10" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
#
#
#
# <rect x="200" y = "10" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
#
#
#
#
# <rect x="10" y = "20" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
# <rect x="30" y = "20" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
# <rect x="50" y = "20" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="60" y = "20" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="70" y = "20" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
#
# <rect x="100" y = "20" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="110" y = "20" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="120" y = "20" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="130" y = "20" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
# <rect x="150" y = "20" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="160" y = "20" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="170" y = "20" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
#
# <rect x="200" y = "20" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="210" y = "20" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="220" y = "20" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
#
#
#
# <rect x="20" y = "30" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
#
# <rect x="50" y = "30" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
#
#
#
# <rect x="100" y = "30" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
#
# <rect x="130" y = "30" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
# <rect x="150" y = "30" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
#
#
#
# <rect x="200" y = "30" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
#
#
#
#
#
# <rect x="20" y = "40" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
#
# <rect x="50" y = "40" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
#
#
#
# <rect x="100" y = "40" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
#
# <rect x="130" y = "40" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
# <rect x="150" y = "40" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
#
#
#
# <rect x="200" y = "40" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
#
#
#
#
#
# <rect x="20" y = "50" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
#
# <rect x="50" y = "50" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="60" y = "50" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="70" y = "50" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="80" y = "50" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
# <rect x="100" y = "50" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
#
# <rect x="130" y = "50" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
# <rect x="150" y = "50" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="160" y = "50" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="170" y = "50" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
# <rect x="180" y = "50" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
# <rect x="200" y = "50" width="10" height="10" style="fill:rgb(0,0,0);stroke-width:0.2;stroke:rgb(255,255,255)" />
#
#
#
# </svg>
