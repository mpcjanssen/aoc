# %%
source [file join . modules util.tcl]

# %%
set data [read-input day08];

# %%
set width 25
set height 6
set layersize [expr {$width*$height}]
set pat [string repeat . $layersize]
set layers [regexp -all -inline $pat $data]

proc freq1s {d} {
  dict get $d 1
}

proc part1 {} {
  set min0freqs [lindex [lsort -integer -index 1 [lmap x $::layers {lsort -integer -stride 2 -index 0 [freq $x]}]] 0]
  return [expr {[dict get $min0freqs 1]*[dict get $min0freqs 2]}]
}

# %%
part1
# Out:
# 2193

# %%
proc visualize-step {} {
  set layer 0
  set svgid [jupyter::html {<svg width="250" height="60"></svg>}]
  yield
  set svg [lrepeat 150 {}]
  foreach l [lreverse $::layers] {
    incr layer
    foreach y [range 0 5] {
       foreach x [range 0 24] {
       set idx [expr {$y*25+$x} ]
        set col [string index $l $idx]
        switch $col {
          0 {
              lset svg $idx {}
          }
          1 {
              lset svg $idx [svgpixel $x $y 0.01]
          }
          
        }
      }
    }
    jupyter::updatehtml $svgid "<b>layer: </b> $layer<br><svg viewbox=\"-1 -1 26 7\">[join $svg \n]</svg>"
    yield 1
  }
  yield 0
}

# %%
coroutine visualize visualize-step
while {[visualize]} {}
# Out:
# <b>layer: </b> 100<br><svg viewbox="-1 -1 26 7"><rect x="0" y = "0" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
#
#
# <rect x="4" y = "0" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="5" y = "0" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="6" y = "0" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="7" y = "0" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="8" y = "0" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
# <rect x="10" y = "0" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
#
# <rect x="13" y = "0" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
# <rect x="15" y = "0" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="16" y = "0" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="17" y = "0" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="18" y = "0" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
# <rect x="20" y = "0" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="21" y = "0" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="22" y = "0" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="23" y = "0" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
# <rect x="0" y = "1" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
#
#
# <rect x="4" y = "1" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="5" y = "1" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
#
#
#
# <rect x="10" y = "1" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
#
# <rect x="13" y = "1" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
# <rect x="15" y = "1" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
#
#
#
# <rect x="20" y = "1" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
#
#
#
#
# <rect x="1" y = "2" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
# <rect x="3" y = "2" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
# <rect x="5" y = "2" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="6" y = "2" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="7" y = "2" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
#
# <rect x="10" y = "2" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="11" y = "2" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="12" y = "2" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="13" y = "2" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
# <rect x="15" y = "2" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="16" y = "2" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="17" y = "2" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
#
# <rect x="20" y = "2" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="21" y = "2" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="22" y = "2" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
#
#
#
# <rect x="2" y = "3" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
#
# <rect x="5" y = "3" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
#
#
#
# <rect x="10" y = "3" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
#
# <rect x="13" y = "3" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
# <rect x="15" y = "3" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
#
#
#
# <rect x="20" y = "3" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
#
#
#
#
#
# <rect x="2" y = "4" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
#
# <rect x="5" y = "4" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
#
#
#
# <rect x="10" y = "4" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
#
# <rect x="13" y = "4" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
# <rect x="15" y = "4" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
#
#
#
# <rect x="20" y = "4" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
#
#
#
#
#
# <rect x="2" y = "5" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
#
# <rect x="5" y = "5" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="6" y = "5" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="7" y = "5" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="8" y = "5" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
# <rect x="10" y = "5" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
#
# <rect x="13" y = "5" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
# <rect x="15" y = "5" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="16" y = "5" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="17" y = "5" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
# <rect x="18" y = "5" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
# <rect x="20" y = "5" width="1" height="1" style="fill:rgb(0,0,0);stroke-width:0.01;stroke:rgb(255,255,255)" />
#
#
#
# </svg>
